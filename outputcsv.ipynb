# %%
#output csv
from urllib import request
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import jieba
import jieba.analyse

def getData(url):
    #set user agent
    req = request.Request(url)
    req.add_header("User-Agent", "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.122 Safari/537.36")
    response = request.urlopen(req)
    data = response.read().decode("utf-8")

    #read data in html format
    html = BeautifulSoup(data,"html.parser")
    
    #set find area
    t = html.find_all("h3", class_= "article-title")
    
    #put into dataframe
    title_list = [p.text.strip() for p in t]
    df = pd.DataFrame({
        'title': title_list
    })
    df['tag'] = np.where(df['title'].str.contains("【錯誤】") == 0, df['title'], "fake")
    
    pd.set_option('max_colwidth',100)
    display(df)

    #find next page url
    nextpage = html.find("a", string = "下一頁 ›")
    return nextpage["href"]
    
#input news article URL
#錯誤https://tfc-taiwan.org.tw/articles/category/26/27
#部分錯誤https://tfc-taiwan.org.tw/articles/category/26/28
targetURL = "https://tfc-taiwan.org.tw/articles/category/26/27"
c = 0
while c<2:
    targetURL = "https://tfc-taiwan.org.tw" + getData(targetURL)
    c+=1
    #print(targetURL)
# Out:
#                                                                           title  \
# 0   【錯誤】網傳影片宣稱「特朗普黑幫全都接種了新冠疫苗！2020年4月20日，特朗普的新冠新聞發布會露出驚天秘密...難怪...特朗普新冠檢測始終陰性」？
# 1                                              【錯誤】網傳「3萬紓困補助...是從勞工自己的勞退金裡挪用的」？
# 2                                【錯誤】網傳「沒撇步⋯只能將佛祖請列出來鎮病毒了...整個JR日本地鐵站里都佈滿阿彌陀佛」？
# 3                    【錯誤】網傳影片宣稱「新妙招，印度捉到沒有戴口罩的市民 ，關到一架救護車裡鎖住 ，裡面有一個假扮確診的患者...」？
# 4                                         【錯誤】網傳簡訊通知「您所郵寄的包裹涉嫌違規操作已退回,請核對退貨地址」？
# 5  【錯誤】網傳「4月25日新聞快報。由於疫情的關係，政府決定幫助國民，無條件每個家庭將會提供援助。援助金可高達50000台幣，連續三個月，申請詳情如下」？
# 6                               【錯誤】網傳圖片宣稱「一位護士在摘掉口罩和眼鏡罩後，在紫外線下顯出臉上仍有殘留的病毒...」？
# 7           【錯誤】網傳「中華民國衛福部長: 陳時中提醒大家~再﻿次﻿﻿強調﻿：別﻿出門，端午節(6月25日)過後，再看疫情﻿控制情況...」﻿？
# 8          【錯誤】網傳影片宣稱「記者探望病愈在家的英國首相強生...他的家真像是遺棄的三綫軍工場舊址...也許是客廳太小只好自己端着茶盤...」？
# 9                            【錯誤】網傳影片搭配文字宣稱「台灣幾乎絕跡 ~獨領台灣山林的雲豹再現蹤影！美麗的花紋，真令人讚嘆」？
#
#     tag
# 0  fake
# 1  fake
# 2  fake
# 3  fake
# 4  fake
# 5  fake
# 6  fake
# 7  fake
# 8  fake
# 9  fake
#                                                          title   tag
# 0  【錯誤】網傳「只要戶籍在新北市，年滿65歲可到區公所帶身份證存摺辦理健保補助金，三千二百二十四元，半年領一次...」？  fake
# 1                          【錯誤】網傳一段影片搭配文字宣稱「外國人，無意間拍攝到的，恐怖哦！」？  fake
# 2                                        【錯誤】網傳影片宣稱「人和猴子交配生子」？  fake
# 3                                  【錯誤】網傳影片宣稱「義大利人民 全國跪地向天懺悔」？  fake
# 4     【錯誤】網傳「美國政府宣導預防中共武漢病毒🦠全民留家不要趴趴走，NitesTV網站所有電影上網免費觀賞...」？  fake
# 5      【錯誤】網傳「美國核動力潛艇田納西號，12月底開始，潛在海裏119天，150員船員，竟然有8名驗出新冠病毒」？  fake
# 6               【錯誤】網傳梳子造型刀照片宣稱「轉傳國教署通知：提請留意，若看到學生拿著梳子，請留心檢查」？  fake
# 7          【錯誤】網傳影片宣稱「義大利這對小兄弟的媽媽給肺炎病毒帶走了...弟弟就往天空不斷的叫喚媽媽...」？  fake
# 8                             【錯誤】網站文章「殯葬業者累倒午睡 被同事誤當屍體 火化死亡」？  fake
# 9                      【錯誤】網傳「之前有老虎確診...請小心遠離家中寵物貓狗及豢養的家禽...」？  fake
