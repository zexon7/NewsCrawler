# %%
#News Crawler
#Get news title and url from Google News

from urllib import request
from bs4 import BeautifulSoup
import pandas as pd

url = "https://news.google.com/topics/CAAqKggKIiRDQkFTRlFvSUwyMHZNRGx1YlY4U0JYcG9MVlJYR2dKVVZ5Z0FQAQ?hl=zh-TW&gl=TW&ceid=TW%3Azh-Hant"

#set user agent
req = request.Request(url)
req.add_header("User-Agent", "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.122 Safari/537.36")
response = request.urlopen(req)
data = response.read().decode("utf-8")

#read data in html format
html = BeautifulSoup(data,"html.parser")

#search for class
titles_data = html.find_all("a",class_="DY5T1d")
titles_source = html.find_all("a",class_="wEwyrc AVN2gc uQIVzc Sksgp")
titles_time = html.find_all("time",class_="WW6dff uQIVzc Sksgp")
#print(titles)

#put title's info into a list
title_list = [t.string for t in titles_data]
url_list = ["https://news.google.com" + u.get("href") for u in titles_data]
source_list = [s.string for s in titles_source]
title_time = [t.get("datetime") for t in titles_time ]

#create a data frame
df = pd.DataFrame({
    'title': title_list,
    'source': source_list,
    'time': title_time,
    'link': url_list
})

#show full data frame setting
#pd.set_option("display.max_rows", None,'display.max_columns', None,'display.max_colwidth', None)
#print(df.head())

pd.set_option('max_colwidth',100)
display(df.head())
# Out:
#                                                                   title  \
# 0                                       網路出現「金正恩遺體照」！ 中東情報：確已腦死│TVBS新聞網
# 1                                       控美捏造死訊和發布UFO影片有共同陰謀「金正恩妹」嗆：去死吧！
# 2                                                    不知金正恩消失！ 脫北者：都不敢討論
# 3  金正恩生死牽動東北亞局勢！若北韓出現政權交替中國與美國.南韓將有合作可能？！｜主播王志郁｜【大世界新聞】20200428｜三立iNEWS
# 4                                                   金正恩為何神隱？ 南韓：為躲避新冠疫情
#
#                  source                  time  \
# 0                TVBS新聞  2020-04-29T13:15:54Z
# 1             Yahoo奇摩新聞  2020-04-29T02:03:00Z
# 2  中時電子報 Chinatimes.com  2020-04-29T08:19:29Z
# 3               三立iNEWS  2020-04-28T15:09:43Z
# 4             udn 聯合新聞網  2020-04-29T10:13:10Z
#
#                                                                                                   link
# 0  https://news.google.com./articles/CAIiEI2WaxofLhah-Vh3PEZi6_MqGQgEKhAIACoHCAowiOqACzDZqfoCMLOkiA...
# 1  https://news.google.com./articles/CBMijwJodHRwczovL3R3Lm5ld3MueWFob28uY29tLyVFNiU4RSVBNyVFNyVCRS...
# 2  https://news.google.com./articles/CAIiEEjoebmAXPqaxtDFxMtALkIqGQgEKhAIACoHCAowk7j0CjCY4qIDMKXQvg...
# 3          https://news.google.com./articles/CCAiC3RfTkh6LVZCN3FJmAEB?hl=zh-TW&gl=TW&ceid=TW%3Azh-Hant
# 4  https://news.google.com./articles/CBMiJ2h0dHBzOi8vdWRuLmNvbS9uZXdzL3N0b3J5LzY4MDkvNDUyNzgyN9IBK2...

# %%
#source filter
sf = df["source"] == "自由時報電子報"
df[sf].head()
# Out:
#                        title   source                  time  \
# 8   美國確診數破百萬 川普：其他國家篩檢遠遠落後美國  自由時報電子報  2020-04-29T05:41:43Z
# 12   武漢肺炎》印度近3萬人確診 官員籲延長全國封鎖  自由時報電子報  2020-04-28T14:59:16Z
# 17  金正恩專列是障眼法？ 脫北議員爆：他不能走不能站  自由時報電子報  2020-04-28T15:05:01Z
# 21       中國別對號入座 澳總理：病毒調查非獵巫  自由時報電子報  2020-04-29T06:28:30Z
# 25       大樂透得獎藏鏡人現身囉！2.43億入袋  自由時報電子報  2020-04-29T07:53:59Z
#
#                                                                                                    link
# 8   https://news.google.com./articles/CBMiN2h0dHBzOi8vbmV3cy5sdG4uY29tLnR3L25ld3Mvd29ybGQvYnJlYWtpbm...
# 12  https://news.google.com./articles/CBMiN2h0dHBzOi8vbmV3cy5sdG4uY29tLnR3L25ld3Mvd29ybGQvYnJlYWtpbm...
# 17  https://news.google.com./articles/CBMiN2h0dHBzOi8vbmV3cy5sdG4uY29tLnR3L25ld3Mvd29ybGQvYnJlYWtpbm...
# 21  https://news.google.com./articles/CBMiN2h0dHBzOi8vbmV3cy5sdG4uY29tLnR3L25ld3Mvd29ybGQvYnJlYWtpbm...
# 25  https://news.google.com./articles/CBMiMmh0dHBzOi8vZWMubHRuLmNvbS50dy9hcnRpY2xlL2JyZWFraW5nbmV3cy...

# %%
#title filter
tf = df["title"].str.contains("肺炎")
df[tf] .head()
# Out:
#                                       title     source                  time  \
# 9                   美國逾5.8萬人死於新冠肺炎 超過越戰陣亡人數  udn 聯合新聞網  2020-04-29T02:16:09Z
# 11  印度13億人口，為何僅千人死於新冠肺炎？專家分析：封城、卡介苗都可能是關鍵原因  Yahoo奇摩新聞  2020-04-29T11:40:00Z
# 12                  武漢肺炎》印度近3萬人確診 官員籲延長全國封鎖    自由時報電子報  2020-04-28T14:59:16Z
# 34                   川普：美新冠肺炎破百萬例係因檢測能力世界最強  udn 聯合新聞網  2020-04-29T08:18:18Z
# 38                         肺炎疫情下華裔美國人的困境與機遇    BBC 中文网  2020-04-29T12:43:42Z
#
#                                                                                                    link
# 9   https://news.google.com./articles/CBMiKWh0dHBzOi8vdWRuLmNvbS9uZXdzL3N0b3J5LzEyMDk0NC80NTI2NTIz0g...
# 11  https://news.google.com./articles/CBMi2AJodHRwczovL3R3Lm5ld3MueWFob28uY29tLyVFNSU4RCVCMCVFNSVCQS...
# 12  https://news.google.com./articles/CBMiN2h0dHBzOi8vbmV3cy5sdG4uY29tLnR3L25ld3Mvd29ybGQvYnJlYWtpbm...
# 34  https://news.google.com./articles/CBMiJ2h0dHBzOi8vdWRuLmNvbS9uZXdzL3N0b3J5LzY4MTMvNDUyNzgwONIBAA...
# 38  https://news.google.com./articles/CBMiMGh0dHBzOi8vd3d3LmJiYy5jb20vemhvbmd3ZW4vdHJhZC93b3JsZC01Mj...

# %%
#List of news source
sourcedf = pd.DataFrame({
    '新聞來源': df.source.unique()
})
display(sourcedf.head(10))
# Out:
#                    新聞來源
# 0                TVBS新聞
# 1             Yahoo奇摩新聞
# 2  中時電子報 Chinatimes.com
# 3               三立iNEWS
# 4             udn 聯合新聞網
# 5               中央社即時新聞
# 6               鉅亨網財經新聞
# 7               自由時報電子報
# 8               加拿大星島日報
# 9                   大紀元
